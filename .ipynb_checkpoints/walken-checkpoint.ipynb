# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# This analysis is to examine if any correlation exists between Christopher Walken's movie career and use of cowbell in popular music.
#
# ![SegmentLocal](walken.gif "segment")

# %% [markdown]
# # METHODOLOGY

# %% [markdown]
# ## Collect Data
#
# ### Christopher Walken's Film Career
#
# The website https://www.rottentomatoes.com/celebrity/christopher_walken was accessed on 10/13/2021. The film list was not so large that it was necessary to use other tools to collect information, so the list was transferred to a spreadsheet, fields with "No Score Yet" or a "-" in the Box Office revenue were deleted.
#
# ### Cowbell Songs
#
# **UltimateCowbell.com**
#
# The best resource with complete listings of cowbell songs was http://ultimatecowbell.com. Smaller lists are available with a much smaller sample size, typically ranging from 10-12 songs. Much more data was needed to determine any patterns that may occur. Note: Some of these entries have explicit language.
#
# Also, the year each song was published would be required to plot correctly against Walken's career. UltimateCowbell only provided the song details with the year as a separate page per song ([see example here](http://ultimatecowbell.com/songview.php?idsongperm=718)). Since the site had well over 4000 entries, the easiest method was to create a web scraper, move the information to a database and write a CSV. The code for the web scraper can be found in `cowbell.py`. Website accessed on 10/14/2021.
#
# **RollingStone.com**
#
# The UltimateCowbell.com list was longer than necessary. The data I am interested in is with mainstream music, across genres such as pop, country, rock, or alternative. I wanted to reduce the data without my own editing or bias, so I located a list of songs to cross-reference and make a new dataframe with those that contained cowbell.
#
# Rolling Stone magazine recently released an updated list of ["The 500 Greatest Songs of All Time"](https://www.rollingstone.com/music/music-lists/best-songs-of-all-time-1224767/kanye-west-stronger-1224837/) on 9/15/2021. The website is dynamic, so my previous webscraper wouldn't load the HTML needed. Since the list is only across 10 webpages, I made a web scraper to run in the website console that would return the artist, song title and year. I copied these fields into a CSV.

# %% [markdown]
# # RESULTS

# %%
# Import libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Use pandas to read CSV
walken = pd.read_csv('c_walken.csv')

# %%
# Check df
walken
# Out:
#      Critics_Score  Audience_Score                         Title  \
# 0             0.29            0.85          The War With Grandpa
# 1             0.25            0.52           Wild Mountain Thyme
# 2             0.20             NaN               The Jesus Rolls
# 3             0.32            0.60             Irreplaceable You
# 4             0.17            0.25                Father Figures
# ..             ...             ...                           ...
# 106           0.96            0.92                    Annie Hall
# 107           0.80            0.64  Next Stop, Greenwich Village
# 108            NaN            0.46            The Mind Snatchers
# 109           0.74            0.54            The Anderson Tapes
# 110            NaN             NaN            Barefoot in Athens
#
#                     Character Box_Revenue  Year
# 0                     Jerry        $21.3M  2020
# 1               Tony Reilly       $194.9K  2020
# 2                    Warden           NaN  2019
# 3                   Unknown           NaN  2018
# 4        Dr. Walter Tinkler        $16.8M  2017
# ..                        ...         ...   ...
# 106              Duane Hall           NaN  1977
# 107           Robert Fulmer           NaN  1976
# 108  Privatz James H. Reese           NaN  1972
# 109                 The Kid           NaN  1971
# 110              Lamprocles           NaN  1966
#
# [111 rows x 6 columns]

# %%
# Copy Revenue column
walken['box'] = walken['Box_Revenue']


# Replace $ and - in copied column
walken['box'] = walken['box'].str.replace('$', '')
walken['box'] = walken['box'].str.replace('-', 'NaN')


# Replace M and K with corresponding 0s
walken['box'] = walken['box'].replace(r'[KM]+$', '', regex=True).astype(float) * \
(walken['box'].str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1).replace(['K','M'], [10**3, 10**6]).astype(int))


# Check Work
total_revenue = walken['box'].sum()
total_formatted = "{:,}".format(total_revenue)

print(walken['box'][0])
print(f"Christopher Walken's movies have made a combined ${total_formatted}")
# Out:
# 21300000.0
# Christopher Walken's movies have made a combined $2,170,409,000.0
# C:\Users\annee\AppData\Local\Temp/ipykernel_8788/3280905787.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   walken['box'] = walken['box'].str.replace('$', '')

# %%
# Add movie revenue if in the same year
walken['year_sum'] = walken.groupby(['Year'])['box'].transform(sum)


#Check work
walken[:10]
# Out:
#    Critics_Score  Audience_Score                        Title  \
# 0           0.29            0.85         The War With Grandpa
# 1           0.25            0.52          Wild Mountain Thyme
# 2           0.20             NaN              The Jesus Rolls
# 3           0.32            0.60            Irreplaceable You
# 4           0.17            0.25               Father Figures
# 5           0.94            0.86              The Jungle Book
# 6           0.14            0.41                   Nine Lives
# 7           0.81            0.82              Eddie the Eagle
# 8           0.10            0.21  Joe Dirt 2: Beautiful Loser
# 9           0.53            0.26                One More Time
#
#               Character Box_Revenue  Year          box     year_sum
# 0               Jerry        $21.3M  2020   21300000.0   21494900.0
# 1         Tony Reilly       $194.9K  2020     194900.0   21494900.0
# 2              Warden           NaN  2019          NaN          0.0
# 3             Unknown           NaN  2018          NaN          0.0
# 4  Dr. Walter Tinkler        $16.8M  2017   16800000.0   16800000.0
# 5           King Louie      $364.0M  2016  364000000.0  399400000.0
# 6       Felix Perkins        $19.6M  2016   19600000.0  399400000.0
# 7        Warren Sharp        $15.8M  2016   15800000.0  399400000.0
# 8                Clem           NaN  2015          NaN     240100.0
# 9                Paul           NaN  2015          NaN     240100.0

# %%
# Sort by box office totals
box_sorted = walken.sort_values(by='box', ascending=True) 
box_sorted
# Out:
#      Critics_Score  Audience_Score                         Title  \
# 73            0.20            0.33             A Business Affair
# 57            0.19            0.38                New Rose Hotel
# 14            0.50            0.38              The Power of Few
# 80            0.72            0.38                      Mistress
# 92             NaN            0.43                      Deadline
# ..             ...             ...                           ...
# 106           0.96            0.92                    Annie Hall
# 107           0.80            0.64  Next Stop, Greenwich Village
# 108            NaN            0.46            The Mind Snatchers
# 109           0.74            0.54            The Anderson Tapes
# 110            NaN             NaN            Barefoot in Athens
#
#                     Character Box_Revenue  Year      box     year_sum
# 73              Vanni Corso         $2.8K  1994   2800.0       2800.0
# 57                      Fox        $20.4K  1998  20400.0   91557000.0
# 14                     Doke        $22.1K  2013  22100.0      22100.0
# 80              Warren Zell        $53.6K  1992  53600.0  160353600.0
# 92              Don Stevens        $86.7K  1987  86700.0      86700.0
# ..                        ...         ...   ...      ...          ...
# 106              Duane Hall           NaN  1977      NaN          0.0
# 107           Robert Fulmer           NaN  1976      NaN          0.0
# 108  Privatz James H. Reese           NaN  1972      NaN          0.0
# 109                 The Kid           NaN  1971      NaN          0.0
# 110              Lamprocles           NaN  1966      NaN          0.0
#
# [111 rows x 8 columns]

# %%
# Define X and Y
# Must have values in Critics_Score, Audience_Score and box to be included
x = box_sorted.dropna(subset=['Critics_Score', 'Audience_Score', 'box']).Critics_Score * 100
x2 = (box_sorted.dropna(subset=['Critics_Score', 'Audience_Score', 'box']).Audience_Score) * 100
y = box_sorted.dropna(subset=['Critics_Score', 'Audience_Score', 'box']).box


# Subplots
fig, ax = plt.subplots(figsize=(15,12))


# Title
ax.set_title('Walken Films Ratings and Box Office Revenue')


# X and Y Axis Labels
plt.xlabel('Score from 0 - 100')
plt.ylabel('USD') 


# Information to Graph
ax.plot(x, y, 'go', alpha=0.5, label='Critics Score')
ax.plot(x2, y, 'bo', alpha=0.5, label='Audience Score')


# Y ticks
def millions(x, pos):
    """The two args are the value and tick position."""
    return '${:1.1f}M'.format(x*1e-6)

ax.yaxis.set_major_formatter(millions)
ax.yaxis.set_tick_params(which='major', labelcolor='green',
                         labelleft=True, labelright=False)


# Show legend
ax.legend()

# Show grid
ax.grid()

# Remove text output
plt.show()

# %%
# Sort by year
year_sorted = walken.sort_values(by='Year', ascending=True) 


# Adjust size
plt.figure(figsize=(15,8))


# Define X and Y
x = year_sorted['Year'].unique()
y = year_sorted['Year'].value_counts().sort_index()


# X and Y Axis Labels
plt.xlabel('Walken Active Film Years')
plt.ylabel('Number of Films per Year') 


# X Ticks- Every three years
plt.xticks(np.arange(min(x), max(x)+1, 3.0))


# Plot the graph
plt.plot(x, y, marker='o')
plt.show()

# %%
# Import CSV of all cowbell songs
songs = pd.read_csv('cowbell1_4247.csv')


# Remove extra quote in string
songs['Song'] = songs['Song'].str.replace('"', '')
songs['Band'] = songs['Band'].str.replace('"', '')

type(songs.Year[255])

songs = songs.loc[songs["Year"] != 0]
songs = songs.loc[songs["Year"] != 'nan']

songs[:10]
# Out:
#                                            Band  \
# 0                                           !!!
# 1                                           !!!
# 2  ...And You Will Know Us by the Trail of Dead
# 3                             Weird Al Yankovic
# 4                             Weird Al Yankovic
# 5                             Weird Al Yankovic
# 6                             Weird Al Yankovic
# 7                             Weird Al Yankovic
# 8                             Weird Al Yankovic
# 9                             Weird Al Yankovic
#
#                                                 Song  \
# 0  Me and Giuliani Down by the School Yard (A Tru...
# 1                                         Hammerhead
# 2                                         Open Doors
# 3               Amish Paradise [Coolio featuring LV]
# 4  Money for Nothing / Beverly Hillbillies [Dire ...
# 5             Pretty Fly For a Rabbi [The Offspring]
# 6                                   This Is the Life
# 7                                  Trash Day [Nelly]
# 8                                 Close but No Cigar
# 9                                         Polka Face
#
#                                                Album  \
# 0  Me and Giuliani Down by the School Yard (A Tru...
# 1                                                !!!
# 2                                         Lost Songs
# 3                                       Bad Hair Day
# 4            UHF: Original Motion Picture Soundtrack
# 5                              Running With Scissors
# 6                                  Dare to Be Stupid
# 7                                         Poodle Hat
# 8                             Straight Outta Lynwood
# 9                                        Alpocalypse
#
#                     Record_Company    Year
# 0                     Touch and Go  2003.0
# 1               Gold Standard Labs  2000.0
# 2  Richter Scale / Superball Music  2012.0
# 3                     Scotti Bros.  1996.0
# 4                         Columbia  1989.0
# 5                          Volcano  1999.0
# 6                     Scotti Bros.  1985.0
# 7                          Volcano  2003.0
# 8                          Volcano  2006.0
# 9                          Volcano  2011.0

# %%
plt.figure(figsize=(15,8))

x = songs.dropna(subset=['Year'])['Year'].unique()
y = songs.dropna(subset=['Year'])['Year'].value_counts().sort_index()

plt.xticks(np.arange(min(x), max(x)+1, 3.0))

plt.plot(x, y, 'go')

# %%
rs500 = pd.read_csv('rs500.csv')

year_500 = rs500.sort_values(by='year', ascending=True) 


# Adjust size
plt.figure(figsize=(15,8))


# Define X and Y
x = year_500['year'].unique()
y = year_500['year'].value_counts().sort_index()

# X and Y Axis Labels
plt.xlabel('Year')
plt.ylabel('Number of "Rolling Stone 500 Greatest" per Year') 


# X Ticks- Every three years
plt.xticks(np.arange(min(x), max(x)+1, 3.0))


# Plot the graph
plt.plot(x, y, marker='o')
plt.show()

# %%
print(rs500.song[60])

rs500['song'] = rs500['song'].str.replace(r"[\"\',']", "")
songs['Song'] = songs['Song'].str.replace(r"[\"\',']", "")
print(rs500.song[60])

print(songs.Song[442])
print(rs500.song[51])
# Out:
# If I Ain't Got You'
# If I Aint Got You
# (Dont Fear) The Reaper
# (Dont Fear) The Reaper
# C:\Users\annee\AppData\Local\Temp/ipykernel_8788/1333973672.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   rs500['song'] = rs500['song'].str.replace(r"[\"\',']", "")
# C:\Users\annee\AppData\Local\Temp/ipykernel_8788/1333973672.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   songs['Song'] = songs['Song'].str.replace(r"[\"\',']", "")

# %%
#songs[songs['Song'].isin(rs500.song)]
rs500[rs500['song'].isin(songs.Song)]
# Out:
#      rank                                     artist  \
# 5     495                                Carly Simon
# 9     491                              Guns N' Roses
# 22    478  Juvenile feat. Lil Wayne and Mannie Fresh
# 31    469                               Dixie Chicks
# 35    465          Daft Punk feat. Pharrell Williams
# 48    452                                       Toto
# 51    449                           Blue Oyster Cult
# 67    433                              Pet Shop Boys
# 73    427                            Sugar Hill Gang
# 84    416                                  Pearl Jam
# 87    413                                       Them
# 105   395   Afrika Bambaataa and the Soulsonic Force
# 111   389                                 Pretenders
# 158   342                                Chuck Berry
# 163   337                                       Cher
# 200   300                                 The B-52's
# 250   250                The Jimi Hendrix Experience
# 260   240                            Backstreet Boys
# 267   233                                  Deee-Lite
# 280   220                                  New Order
# 290   210                                 Funkadelic
# 293   207                   Rage Against the Machine
# 350   150                                  Green Day
# 391   109                   Sly and the Family Stone
# 403    97                                Patti Smith
# 404    96                                      Jay-Z
# 412    88                              Guns N' Roses
# 432    68                                       Chic
# 435    65                      Earth, Wind, and Fire
# 443    57                   Sly and the Family Stone
# 448    52                               Donna Summer
# 472    28                              Talking Heads
#
#                           song  year
# 5                Youre So Vain  1972
# 9        Welcome to the Jungle  1987
# 22            Back That Azz Up  1998
# 31                Goodbye Earl  2000
# 35                   Get Lucky  2013
# 48                      Africa  1982
# 51      (Dont Fear) The Reaper  1976
# 67              West End Girls  1984
# 73             Rappers Delight  1979
# 84                       Alive  1991
# 87                      Gloria  1965
# 105                Planet Rock  1982
# 111            Brass in Pocket  1979
# 158              Promised Land  1964
# 163                    Believe  1998
# 200               Rock Lobster  1978
# 250                Purple Haze  1967
# 260         I Want It That Way  1999
# 267     Groove Is in the Heart  1990
# 280      Bizarre Love Triangle  1986
# 290  One Nation Under a Groove  1978
# 293        Killing in the Name  1992
# 350                Basket Case  1994
# 391            Everyday People  1968
# 403                     Gloria  1975
# 404                99 Problems  2003
# 412         Sweet Child O Mine  1987
# 432                 Good Times  1979
# 435                  September  1978
# 443              Family Affair  1971
# 448                I Feel Love  1977
# 472         Once in a Lifetime  1980

# %% [markdown]
# # CONCLUSION
